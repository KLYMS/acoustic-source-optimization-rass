# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# df_t = pd.read_csv('/home/murali/Documents/rass/simulation/ideal_wTemp.csv')
df_w = pd.read_csv('/home/murali/Documents/rass/simulation/wTemp_wWind.csv')

# %%
df = df_t
plt.scatter(df['x'],df['z'])

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((0,dist))
plt.title("altitude v/s  distance with temp")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()
plt.show()

# %%
df_w
# Out:
#                  x  y           z     theta
# 0     0.000000e+00  0       0.000  -1.57080
# 1    -1.514820e+03  0     628.826   1.23043
# 2     7.048050e+01  0     953.759   2.12587
# 3     1.158750e+03  0    1344.590  -6.66402
# 4     5.603010e+02  0    1396.510  45.60060
# ...            ... ..         ...       ...
# 5095 -5.702840e+06  0 -167704.000  21.42250
# 5096 -7.410330e+06  0 -259353.000  23.44670
# 5097 -1.008010e+07  0 -339874.000  17.88250
# 5098 -1.351900e+07  0 -372303.000   9.84362
# 5099 -1.731980e+07  0 -512656.000   8.37426
#
# [5100 rows x 4 columns]

# %%
df = df_w
plt.scatter(df['x'],df['z'])

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((0,dist))
plt.title("altitude v/s  distance with temp and wind")
plt.xlabel("distance")
plt.ylabel("altitude")

plt.grid()
plt.show()
