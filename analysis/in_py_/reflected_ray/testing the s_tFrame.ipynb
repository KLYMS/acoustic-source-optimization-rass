# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import RBFInterpolator

# %%
df = pd.read_csv('/home/murali/Documents/rass/data/sim_data/dived_data/cpp_data/alglib_CS_i_0/backscatter_coordinates_i_0_s_G375-r0.15.csv')
df
# Out:
#           x_val  y_val    z_val      x_land     y_land      phi    theta
# 0      -27799.2    0.0  4275.16 -105.823437  87.657579  0.00000 -1.41820
# 1      -27178.5    0.0  7238.89   25.245992   5.057230  0.00000 -1.31049
# 2      -27112.4    0.0  7482.55  122.649823   1.431660  0.00000 -1.30152
# 3      -27044.2    0.0  7725.61   17.751727  -2.045131  0.00000 -1.29254
# 4      -26973.7    0.0  7968.04  -53.540530  -0.959751  0.00000 -1.28356
# ...         ...    ...      ...         ...        ...      ...      ...
# 536806 -26973.7    0.0  7968.04  -53.540530  -0.959751  3.14159  1.26561
# 536807 -27044.2    0.0  7725.61   17.751727  -2.045131  3.14159  1.27459
# 536808 -27112.4    0.0  7482.55  122.649823   1.431660  3.14159  1.28356
# 536809 -27178.5    0.0  7238.89   25.245992   5.057230  3.14159  1.29254
# 536810 -27799.2    0.0  4275.16 -105.823437  87.657579  3.14159  1.40025
#
# [536811 rows x 7 columns]

# %%
# 375, 0.15

plt.figure(figsize=(21, 7))

plt.subplot(1, 2, 1)
plt.scatter(df['x_val'],df['z_val'], s=0.9)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((0,dist))
plt.title("N-S")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()

plt.subplot(1, 2, 2)
plt.scatter(df['y_val'],df['z_val'], s=0.9)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((-dist,dist))
plt.title("E-W")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()

plt.show()

# %%
# 375, 0.05

plt.figure(figsize=(21, 7))

plt.subplot(1, 2, 1)
plt.scatter(df['x_val'],df['z_val'], s=0.9)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((0,dist))
plt.title("N-S")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()

plt.subplot(1, 2, 2)
plt.scatter(df['y_val'],df['z_val'], s=0.9)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((-dist,dist))
plt.title("E-W")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()

plt.show()

# %%
# 500, 0.05

plt.figure(figsize=(21, 7))

plt.subplot(1, 2, 1)
plt.scatter(df['x_val'],df['z_val'], s=0.9)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((0,dist))
plt.title("N-S")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()

plt.subplot(1, 2, 2)
plt.scatter(df['y_val'],df['z_val'], s=0.9)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((-dist,dist))
plt.title("E-W")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()

plt.show()

# %%
# 400, 0.05

plt.figure(figsize=(21, 7))

plt.subplot(1, 2, 1)
plt.scatter(df['x_val'],df['z_val'], s=0.9)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((0,dist))
plt.title("N-S")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()

plt.subplot(1, 2, 2)
plt.scatter(df['y_val'],df['z_val'], s=0.9)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((-dist,dist))
plt.title("E-W")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()

plt.show()

# %%
# 450, 0.15

plt.figure(figsize=(21, 7))

plt.subplot(1, 2, 1)
plt.scatter(df['x_val'],df['z_val'], s=0.9)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((0,dist))
plt.title("N-S")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()

plt.subplot(1, 2, 2)
plt.scatter(df['y_val'],df['z_val'], s=0.9)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((-dist,dist))
plt.title("E-W")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()

plt.show()

# %%
# 450, 0.5

plt.figure(figsize=(21, 7))

plt.subplot(1, 2, 1)
plt.scatter(df['x_val'],df['z_val'], s=0.9)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((0,dist))
plt.title("N-S")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()

plt.subplot(1, 2, 2)
plt.scatter(df['y_val'],df['z_val'], s=0.9)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((-dist,dist))
plt.title("E-W")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()

plt.show()

# %%
# 400, 0.5

plt.figure(figsize=(21, 7))

plt.subplot(1, 2, 1)
plt.scatter(df['x_val'],df['z_val'], s=0.9)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((0,dist))
plt.title("N-S")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()

plt.subplot(1, 2, 2)
plt.scatter(df['y_val'],df['z_val'], s=0.9)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((-dist,dist))
plt.title("E-W")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()

plt.show()

# %%
# 375, 0.25

plt.figure(figsize=(21, 7))

plt.subplot(1, 2, 1)
plt.scatter(df['x_val'],df['z_val'], s=0.9)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((0,dist))
plt.title("N-S")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()

plt.subplot(1, 2, 2)
plt.scatter(df['y_val'],df['z_val'], s=0.9)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((-dist,dist))
plt.title("E-W")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()

plt.show()

# %%
# 375, 0.5

plt.figure(figsize=(21, 7))

plt.subplot(1, 2, 1)
plt.scatter(df['x_val'],df['z_val'], s=0.9)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((0,dist))
plt.title("N-S")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()

plt.subplot(1, 2, 2)
plt.scatter(df['y_val'],df['z_val'], s=0.9)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((-dist,dist))
plt.title("E-W")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()

plt.show()

# %%
# 375, 1

plt.figure(figsize=(21, 7))

plt.subplot(1, 2, 1)
plt.scatter(df['x_val'],df['z_val'], s=0.9)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((0,dist))
plt.title("N-S")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()

plt.subplot(1, 2, 2)
plt.scatter(df['y_val'],df['z_val'], s=0.9)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((-dist,dist))
plt.title("E-W")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()

plt.show()

# %%
# 400, 1

plt.figure(figsize=(21, 7))

plt.subplot(1, 2, 1)
plt.scatter(df['x_val'],df['z_val'], s=0.9)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((0,dist))
plt.title("N-S")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()

plt.subplot(1, 2, 2)
plt.scatter(df['y_val'],df['z_val'], s=0.9)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((-dist,dist))
plt.title("E-W")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()

plt.show()

# %%
df = pd.read_csv('/home/murali/Documents/rass/simulation/in_py/reflected_waves/backscatter_coordinates_i_0_s_G250-r5.csv')
df
# Out:
#           x_val  y_val    z_val     x_land    y_land      phi    theta
# 0      -26056.9    0.0  10588.2 -64.159676  2.875477  0.00000 -1.19381
# 1      -25960.8    0.0  10821.6 -11.509948  2.443518  0.00000 -1.18483
# 2      -25862.6    0.0  11054.2  22.144311  1.926222  0.00000 -1.17585
# 3      -25762.4    0.0  11285.9  40.282465  1.410968  0.00000 -1.16688
# 4      -25660.0    0.0  11516.7  46.720842  0.940488  0.00000 -1.15790
# ...         ...    ...      ...        ...       ...      ...      ...
# 480735 -25660.0    0.0  11516.7  46.720842  0.940488  3.14159  1.08609
# 480736 -25762.4    0.0  11285.9  40.282465  1.410968  3.14159  1.09507
# 480737 -25862.6    0.0  11054.2  22.144311  1.926222  3.14159  1.10405
# 480738 -25960.8    0.0  10821.6 -11.509948  2.443518  3.14159  1.11302
# 480739 -26056.9    0.0  10588.2 -64.159676  2.875477  3.14159  1.12200
#
# [480740 rows x 7 columns]

# %%
# 250, 3

plt.figure(figsize=(21, 7))

plt.subplot(1, 2, 1)
plt.scatter(df['x_val'],df['z_val'], s=0.9)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((0,dist))
plt.title("N-S")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()

plt.subplot(1, 2, 2)
plt.scatter(df['y_val'],df['z_val'], s=0.9)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((0,dist))
plt.title("E-W")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()

plt.show()

# %%
# 320, 1

plt.figure(figsize=(21, 7))

plt.subplot(1, 2, 1)
plt.scatter(df['x_val'],df['z_val'], s=0.9)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((0,dist))
plt.title("N-S")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()

plt.subplot(1, 2, 2)
plt.scatter(df['y_val'],df['z_val'], s=0.9)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((0,dist))
plt.title("E-W")
plt.xlabel("distance")
plt.ylabel("altitude")
plt.grid()

plt.show()
