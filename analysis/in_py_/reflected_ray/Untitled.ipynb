# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits import mplot3d
from scipy.interpolate import CubicSpline
from numpy.polynomial.polynomial import Polynomial

# %%
df = pd.read_csv('/home/murali/Documents/rass/simulation/in_py/wTemp.csv')
plt.figure(figsize=(10, 6))
plt.scatter(df['y'],df['z'], s=0.5)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((0,dist))
plt.title("Ideal Conditions with Teperature ")
plt.xlabel("distance")
plt.ylabel("altitude")

plt.grid()
plt.show()

# %%
df = pd.read_csv('/home/murali/Documents/rass/simulation/in_py/wTemp_wWind.csv')
plt.figure(figsize=(10, 6))
plt.scatter(df['y'],df['z'], s=0.5)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((0,dist))
# plt.title("Ideal Conditions with Teperature ")
plt.xlabel("distance")
plt.ylabel("altitude")

plt.grid()
plt.show()

# %%
df = pd.read_csv('/home/murali/Documents/rass/simulation/in_py/wTemp_wWind.csv')
plt.figure(figsize=(10, 6))
plt.scatter(df['x'],df['z'], s=0.5)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((0,dist))
# plt.title("Ideal Conditions with Teperature ")
plt.xlabel("distance")
plt.ylabel("altitude")

plt.grid()
plt.show()

# %%
df = pd.read_csv('/home/murali/Documents/rass/simulation/in_py/wTemp.csv')
df
# Out:
#                   x    y            z     theta  time
# 0          0.000000  0.0     0.000000 -1.570796   0.0
# 1       -510.133847  0.0     0.331176 -1.569498   1.5
# 2      -1020.266835  0.0     1.324702 -1.568200   3.0
# 3      -1530.398102  0.0     2.980575 -1.566901   4.5
# 4      -2040.526790  0.0     5.298790 -1.565603   6.0
# ...             ...  ...          ...       ...   ...
# 22745  30347.428522  0.0  2393.028429  1.393598  90.0
# 22746  30842.843074  0.0  2480.464045  1.397739  91.5
# 22747  31338.576841  0.0  2567.178703  1.397514  93.0
# 22748  31834.243891  0.0  2653.996497  1.396285  94.5
# 22749  32329.113377  0.0  2742.839019  1.390036  96.0
#
# [22750 rows x 5 columns]

# %%
df = pd.read_csv('/home/murali/Documents/rass/simulation/in_py/wTemp_cs.csv')
plt.figure(figsize=(10, 6))
plt.scatter(df['x'],df['z'], s=0.5)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((0,dist))
plt.title("with Teperature spline interp ")
plt.xlabel("distance")
plt.ylabel("altitude")

plt.grid()
plt.show()

# %%
df = pd.read_csv('/home/murali/Documents/rass/simulation/in_py/wTemp.csv')
plt.figure(figsize=(10, 6))
plt.scatter(df['x'],df['z'], s=0.5)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((0,dist))
plt.title("with Teperature  own interp")
plt.xlabel("distance")
plt.ylabel("altitude")

plt.grid()
plt.show()

# %%
df = pd.read_csv('/home/murali/Documents/rass/simulation/in_py/wTemp_wWind.csv')
plt.figure(figsize=(10, 6))
plt.scatter(df['x'],df['z'], s=0.5)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((0,dist))
plt.title("With Temp and Wind, own interp")
plt.xlabel("distance")
plt.ylabel("altitude")

plt.grid()
plt.show()

# %%
df = pd.read_csv('/home/murali/Documents/rass/simulation/in_py/wTemp_wWind.csv')
plt.figure(figsize=(10, 6))
plt.scatter(df['x'],df['z'], s=0.5)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((0,dist))
plt.title("With Temp and Wind, spline interp")
plt.xlabel("distance")
plt.ylabel("altitude")

plt.grid()
plt.show()

# %%
df = pd.read_csv('/home/murali/Documents/rass/simulation/in_py/wTemp.csv')
plt.figure(figsize=(10, 6))
plt.scatter(df['x'],df['z'], s=0.5)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((0,dist))
plt.title("With Temp and Wind, own interp")
plt.xlabel("distance")
plt.ylabel("altitude")

plt.grid()
plt.show()

# %%
df = pd.read_csv('/home/murali/Documents/rass/simulation/in_py/wTemp_wWind.csv')
plt.figure(figsize=(10, 6))
plt.scatter(df['x'],df['z'], s=0.5)

dist = 35 * 1000
plt.xlim((-dist,dist))
plt.ylim((0,dist))
plt.title("With Temp and Wind, own interp")
plt.xlabel("distance")
plt.ylabel("altitude")

plt.grid()
plt.show()
